# %%
import pandas as pd
import requests

# %%
# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/countries-enrolled-in-glass-surveillance-of-antimicrobial-consumption-and-resistance.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# %%
# Fetch the metadata
metadata = requests.get("https://ourworldindata.org/grapher/countries-enrolled-in-glass-surveillance-of-antimicrobial-consumption-and-resistance.metadata.json?v=1&csvType=full&useColumnShortNames=true").json()

# %%
df.head()
# Out:
#         entity code  year enrolment
# 0  Afghanistan  AFG  2024      Both
# 1      Albania  ALB  2024   Neither
# 2      Algeria  DZA  2024  AMR only
# 3      Andorra  AND  2024   Neither
# 4       Angola  AGO  2024  AMR only
